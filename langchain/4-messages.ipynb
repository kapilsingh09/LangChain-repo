# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model(
    
    "google_genai:gemini-3.5-flash",
)

# %%
model.invoke("please tell what is artificial intelligence in simple words?")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'In very simple words: \n\n**Artificial Intelligence (AI) is making computers and machines "smart" so they can think, learn, and make decisions just like humans do.**\n\nNormally, computers can only do what we program them to do. But with AI, computers can learn from experience and figure things out on their own.\n\nHere is an easy way to understand how it works:\n\n### The "Child" Analogy\nImagine teaching a child what a dog is. You don\'t give them a list of rules (like "it must have four legs and fur"). Instead, you show them pictures of dogs. Eventually, the child\'s brain figures out what a dog looks like. \n\n**AI does the same thing.** We show a computer millions of pictures of dogs, and it "learns" to recognize a dog on its own.\n\n---\n\n### AI in Your Everyday Life\nYou probably use AI every day without realizing it:\n* **Netflix or YouTube:** It looks at what you watched in the past and guesses what you’ll want to watch next.\n* 
# ...

# %% [markdown]
# ## Text prompts

# %%
model.invoke("what is langchain?")
# Out:
# AIMessage(content=[{'type': 'text', 'text': '**LangChain** is an open-source framework designed to simplify the creation of applications that use Large Language Models (LLMs) like OpenAI\'s GPT-4, Google\'s Gemini, or open-source models like Llama. \n\nIn simple terms: **If an LLM is a powerful "brain," LangChain is the nervous system, hands, and feet that connect that brain to the rest of the world.**\n\nWhile LLMs are highly capable, they have limitations: they don\'t know your private data, they don\'t have access to the live internet (by default), and they can\'t "remember" long conversations easily. LangChain solves these problems.\n\n---\n\n### Why do developers use LangChain?\nWithout LangChain, writing code to connect an LLM to a database, keep track of chat history, and API endpoints requires writing a massive amount of custom, repetitive code. \n\nLangChain provides standard, ready-to-use building blocks to build AI applications quickly.\n\n---\n\n### Core Concepts of LangC
# ...

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages=[
    SystemMessage(content="You are a poetry expert."),
    HumanMessage(content="Write a poem about artificial intelligence."),

]

response = model.invoke(messages)

response.content['text']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       3 messages=[
#       4     SystemMessage(content="You are a poetry expert."),
#       5     HumanMessage(content="Write a poem about artificial intelligence."),
#       6
#       7 ]
#       9 response = model.invoke(messages)
# ---> 11 response.content['text']
#
# TypeError: list indices must be integers or slices, not str

# %%
system_msg = SystemMessage(content="You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage(content="Write a python function to calculate the factorial of a number."),
]

response = model.invoke(messages)
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Here are three different ways to calculate the factorial of a number in Python, depending on your needs. \n\n### 1. Iterative Approach (Recommended)\nThis is the most practical way to write it from scratch. It uses a loop, making it highly efficient and safe from stack overflow errors on large numbers.\n\n```python\ndef factorial(n):\n    # Check if the input is an integer\n    if not isinstance(n, int):\n        raise TypeError("Factorial is only defined for integers.")\n    # Check if the input is negative\n    if n < 0:\n        raise ValueError("Factorial is not defined for negative numbers.")\n\n    result = 1\n    for i in range(2, n + 1):\n        result *= i\n    return result\n\n\n# Example usage:\nprint(factorial(5))  # Output: 120\nprint(factorial(0))  # Output: 1\n```\n\n---\n\n### 2. Recursive Approach\nThis is the classic computer science approach. It is elegant and maps directly to the mathematical definition of a factorial ($n! = n \\times (
# ...

# %%
#Detailed infomation to the llm through system message
from langchain.messages import SystemMessage, HumanMessage, AIMessage

system_msg = SystemMessage(""" You are a helpful coding assistant. You will be provided with a task and you will provide the code for that task in python. """
)

messages = [
    system_msg,
    HumanMessage(content="Write a python function to calculate the factorial of a number."),
]
response = model.invoke(messages)
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Here is a Python function to calculate the factorial of a number. \n\nThis implementation uses an **iterative approach**, which is efficient and avoids the recursion limit for larger numbers. It also includes error handling for negative numbers.\n\n```python\ndef factorial(n):\n    """Calculates the factorial of a non-negative integer n."""\n    # Check if the input is a negative number\n    if n < 0:\n        raise ValueError("Factorial is not defined for negative numbers.")\n\n    # Check if the input is an integer\n    if not isinstance(n, int):\n        raise TypeError("Factorial is only defined for integers.")\n\n    result = 1\n    for i in range(1, n + 1):\n        result *= i\n\n    return result\n\n\n# --- Examples of usage ---\nprint(factorial(5))  # Output: 120  (5 * 4 * 3 * 2 * 1)\nprint(factorial(0))  # Output: 1    (0! is defined as 1)\nprint(factorial(1))  # Output: 1\n```\n\n### Alternative Approaches:\n\n#### 1. Recursive Approach\nIf you p
# ...

# %%
human_msg = HumanMessage(
    content='Hello!',
    name='alice',
    id='msg-1',
)

# %%
response = model.invoke([human_msg])
response.content
# Out:
# [{'type': 'text',
#   'text': 'Hello! How can I help you today?',
#   'extras': {'signature': '...'}}]

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\karan\Desktop\clean desktop\langchain\.venv\lib\site-packages\langchain_google_genai\chat_models.py:3302, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3301 try:
# -> 3302     response: GenerateContentResponse = self.client.models.generate_content(
#    3303         **request,
#    3304     )
#    3305 except ClientError as e:
#
# File c:\Users\karan\Desktop\clean desktop\langchain\.venv\lib\site-packages\google\genai\models.py:6558, in Models.generate_content(self, model, contents, config)
#    6557 i += 1
# -> 6558 response = self._generate_content(
#    6559     model=model, contents=contents, config=parsed_config_to_call
#    6560 )
#    6562 if not function_map:
#
# ...

# %%
response.usage_metadata
# Out:
# {'input_tokens': 3,
#  'output_tokens': 207,
#  'total_tokens': 210,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 198}}
